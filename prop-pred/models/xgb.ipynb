# %%
import torch
import pandas as pd
import matplotlib.pyplot as plt

# %%
data = pd.read_csv('../../immunomodulation.csv')

# %%
data
# Out:
#      Catalog  PME Code                                             SMILES  \
# 0      S1430   Primary                    COc1ccc(C2CNC(=O)C2)cc1OC1CCCC1
# 1      S1431   Primary  CCCc1nn(C)c2c(=O)[nH]c(-c3cc(S(=O)(=O)N4CCN(C)...
# 2      S1432   Primary  CNS(=O)(=O)Cc1ccc2[nH]cc(CCN(C)C)c2c1.O=C(O)CC...
# 3      S1437   Primary                        Cl.Clc1ccc2nsnc2c1NC1=NCCN1
# 4      S1438   Primary         CC1(C)OC2COC3(COS(N)(=O)=O)OC(C)(C)OC3C2O1
# ...      ...       ...                                                ...
# 3555   27374  PME-6025             CC(C)(C)n1cnc2cc(N=Cc3ccc(Cl)cc3)ccc21
# 3556   26799  PME-6026                 Br.CCCCn1c(=N)n(CC(=O)OC)c2ccccc21
# 3557   27999  PME-6027  COc1ccc(C=NNC(=O)CSc2nnc(-c3ccccc3)n2-c2ccccc2...
# 3558   28078  PME-6028           NS(=O)(=O)c1ccc2c(c1)C1C=CCC1C(C(=O)O)N2
# 3559   28134  PME-6029  COc1ccc(Cn2c(SC)nc3c(c2=O)C2(CCCCC2)Cc2ccccc2-...
#
#       Viability Mask 1  Viability Mask 2   LPS Abs  LPS Abs Std   LPS Lum  \
# ...

# %%
plt.hist(data['Viability Mask 1'], bins=32);

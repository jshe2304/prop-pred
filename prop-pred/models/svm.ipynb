# %%
import pandas as pd
import numpy as np
from sklearn import svm

from utils import Fingerprinter

# %%
data = pd.concat((pd.read_csv('../train.csv'), pd.read_csv('../test.csv')))

# %%
fingerprinter = Fingerprinter()

# %%
fps = fingerprinter(data['SMILES'].tolist())
